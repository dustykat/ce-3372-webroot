# %% [markdown]
# ### CE 3372: Water Systems Design Quiz
#
# **1. What is the primary software used for modeling drinking water systems in this course?**
# - a) HEC-HMS
# - b) EPANET ✅
# - c) AutoCAD
# - d) MODFLOW
#
# **2. What are the three types of water systems defined in the course materials?**
# - a) Municipal, industrial, and agricultural systems
# - b) Water-control, water-use, and environmental restoration systems ✅
# - c) Groundwater, surface water, and wastewater systems
# - d) Residential, commercial, and urban systems
#
# **3. What is the main goal of the Pecos, TX water supply project?**
# - a) Redesign the city’s stormwater system
# - b) Optimize wastewater treatment
# - c) Design components to transport water from an alternate wellfield ✅
# - d) Implement flood control systems
#
# **4. Which ABET outcome is specifically addressed through teamwork in this course?**
# - a) Ability to apply knowledge of mathematics
# - b) Ability to function on multidisciplinary teams ✅
# - c) Understanding of professional and ethical responsibility
# - d) Ability to engage in life-long learning
#
# **5. What is the purpose of intermediate storage facilities in the Pecos water supply project?**
# - a) To serve as emergency reservoirs ✅
# - b) To increase water pressure
# - c) To store stormwater runoff
# - d) To treat raw water before distribution
#
# **6. How should the energy grade line and pressure profile be presented in the Pecos water supply project?**
# - a) As simple line graphs without context
# - b) Using plots identifying critical points of low and high pressure ✅
# - c) Through a series of photos
# - d) As a list of numbers in a table
#
# **7. What is the minimum course expectation for project presentations?**
# - a) Only one team member needs to present
# - b) They must demonstrate communication proficiency and technical understanding ✅
# - c) They should focus on financial feasibility exclusively
# - d) Visuals are optional
#
# **8. What must be included in the design report for the Pecos water supply project?**
# - a) A list of all team members’ individual tasks
# - b) Detailed layouts, hydraulic modeling results, and valve placement ✅
# - c) A PowerPoint summary of the report
# - d) Recommendations for a new treatment plant
#
# **9. In the LIA Industrial Park project, what are students required to calculate?**
# - a) Pump efficiency rates
# - b) The required drainage capacity ✅
# - c) The total construction cost of the site
# - d) The evaporation rates of stormwater
#
# **10. What is the maximum estimated daily water production of the Pecos alternate wellfield?**
# - a) 2.5 MGD
# - b) 3.02 MGD ✅
# - c) 3.9 MGD
# - d) 9.5 MGD

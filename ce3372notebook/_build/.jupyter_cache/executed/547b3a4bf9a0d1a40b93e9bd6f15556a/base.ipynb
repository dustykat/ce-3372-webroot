# %%
# compute area in acres
7540147.046*(3.28)*(3.28)*(1/43560)
# Out:
# 1862.2570702407345

# %%
# count squares
howmany = 270
# size
howbig = howmany*525*525/43560
print(howbig)
# Out:
# 1708.4194214876034

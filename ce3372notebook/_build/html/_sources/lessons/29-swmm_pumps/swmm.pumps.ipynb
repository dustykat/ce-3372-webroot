# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b><h1>CE 3372 Water Systems Design</h1></b>
# </div>
#
# # SWMM Pumps
#
# Use [Dual Drainage Pumps and Lift Stations](http://54.243.252.9/ce-3372-webroot/ce3372notebook/lessons/29-swmm_pumps/CE3372-Lecture-22.pdf) to discuss pumps in SWMM
#
# Use [WoodlandsNoSewer](http://54.243.252.9/ce-3372-webroot/ce3372notebook/lessons/29-swmm_pumps/WoodlandsNoSewer) to illustrate localized flooding.
#
# Use [WoodlandsReliefSewer](http://54.243.252.9/ce-3372-webroot/ce3372notebook/lessons/29-swmm_pumps/WoodlandsReliefSewer) to illustrate non-pumpin solution to localized flooding.
#
# Use [WoodlandsLiftStation](http://54.243.252.9/ce-3372-webroot/ce3372notebook/lessons/29-swmm_pumps/WoodlandsLiftStation) to illustrate lift-station solution to localized flooding.
#
#
# :::{tip}
# Future revision move contents above into proper JupyterBook structure below:
#
# ## Concepts
#
# ## Devices
#
# ## Performance Estimation
#
# :::

# %% [markdown]
# ## End of Section

# %% [markdown]
# # Syllabus

# %% [raw]
# import sys, subprocess; hostname = subprocess.check_output("hostname", shell=True, text=True).strip(); username = subprocess.check_output("whoami", shell=True, text=True).strip(); python_executable = sys.executable; python_version = sys.version; python_version_info = sys.version_info; print(f"Hostname: {hostname}\n" f"User: {username}\n" f"Python Executable: {python_executable}\n" f"Python Version: {python_version}\n" f"Python Version Info: {python_version_info}")

# %% [markdown]
# ## CE 3372 Water Systems Design
#
# ## Course Catalog Description:
#
# ## Prerequisites:
# CE 3305 or equivalent

# %%
# %%html
# <style> table {margin-left: 0 !important;} </style>
# Out:
# <style> table {margin-left: 0 !important;} </style>

# %% [markdown]
# <font color='white'>%%html</font>
# <style> table {margin-left: 0 !important;} </style>
# ## Course Sections
# Lesson time, days, and location:
# | Section | Time and Day | Room | TA |
# |---------|--------------|----------|----------|
# |301 | 1400-1450 M,W,F| CE 205 | None authorized |

# %% [markdown]
# ## Course Instructor:
#
# Instructor: Theodore G. Cleveland, Ph.D., P.E., M. ASCE, F. EWRI
#
# Email: theodore.cleveland@ttu.edu  (put CE 3372 in subject line for email related to this class)
#
# Office location: CECE 203F
#
# Office hours: TBD

# %% [markdown]
# ## Teaching Assistant(s):
#
# 1. TBD email: TBD@ttu.edu (put CE 3105 in subject line for email related to this class)
# 2. TBD email: TBD@ttu.edu (put CE 3105 in subject line for email related to this class)

# %% [markdown]
# ## Textbook(s):
# [Laboratory Manual/Instructor Notes](http://54.243.252.9/ce-3105-webroot/1-LabManual/_build/html/intro.html) serve as the textbook.
#
# [Supplimental Readings](http://54.243.252.9/ce-3105-webroot/3-Readings/) if any, are stored on the class server.

# %% [markdown]
# ## Course Objectives:
#
# This course aims to enhance students’ understanding of the behavior of real fluids and their interactions with physical systems through hands-on experimentation and theoretical analysis. By engaging in the experimental method, students will develop critical thinking and problem-solving skills. The course also emphasizes improving technical writing proficiency and preparing students for the fluid mechanics section of the FE Exam. Collaborative group work is a cornerstone of this course, with peer assessment contributing to a portion of the final grade.

# %% [markdown]
# ## Knowledge, Skills, Abilities (KSA) :
# By the end of this course, students will be able to:
#
# 1. Analyze and solve fluid mechanics problems using measured and tabulated fluid properties with appropriate units.
# 2. Solve manometer problems by applying the fundamental equations of fluid statics.
# 3. Calculate pressures, forces, and lines of action for fluids at rest on plane and curved surfaces.
# 4. Define and evaluate control volumes in fluid flow systems.
# 5. Apply the principles of conservation of mass, energy, and momentum to control volumes.
# 6. Predict the effects of channel transitions, such as changes in width or bed level, in open channel flow problems.
# 7. Compare and contrast the behavior of real and theoretical fluids based on experimental observations.
# 8. Develop step-by-step protocols for conducting fluid mechanics experiments and collecting reliable data.
# 9. Measure values such as head, discharge, and fluid properties using legacy techniques to support calculations involving conservation laws.
# 10. Measure values such as pressure and discharge using modern automated methods, including DIY data loggers and digital and analog sensors, to support conservation law applications.
# 11. Write effective, concise reports that clearly document experimental methods, data analysis, and conclusions, emphasizing technical accuracy and professional presentation.

# %% [markdown]
# ## ABET Student Outcomes
# This course specifically addresses the outcomes listed below.  **Only the primary outcome is assessed** as part of the CECE Continuous Improvement Program.
#
# **Primary Outcomes**
# 1. (6.) an ability to develop and conduct appropriate experimentation, analyze and
# interpret data, and use engineering judgment to draw conclusions
#
# **Secondary Outcomes**
# 1. (1.) An ability to identify, formulate, and solve complex engineering problems by applying principles of engineering, science, and mathematics.
# 2. (7.) An ability to acquire and apply new knowledge as needed, using appropriate learning strategies.
#
# :::{admonition} **About ABET EAC Criteria**
#
# The outcomes above (primary and secondary) are a subset of those prescribed in ABET EAC General Criteria for Bacculerate Programs
#
# >**Criteria 3, Student Outcomes** The program must have documented student outcomes that support the program
# educational objectives. Attainment of these outcomes prepares graduates to enter the
# professional practice of engineering. Student outcomes are outcomes (1) through (7),
# plus any additional outcomes that may be articulated by the program.
#
# The primary outcomes (above) are assessed as part of the CECE Continuous Improvement Program that is prescribed in ABET EAC General Criteria for Bacculerate Programs
#
# > **Criteria 4, Continuous Improvement**: The program must regularly use appropriate, documented processes for assessing and
# evaluating the extent to which the student outcomes are being attained. The results of these evaluations must be systematically utilized as input for the program’s continuous improvement actions. Other available information may also be used to assist in the continuous improvement of the program.
#
# ABET (2024) Criteria for Accrediting ENGINEERING PROGRAMS. 415 North Charles St., Baltimore, MD 21201 \@ [https://www.abet.org/wp-content/uploads/2023/03/23-24-EAC-Criteria_FINAL2.pdf](https://www.abet.org/wp-content/uploads/2023/03/23-24-EAC-Criteria_FINAL2.pdf).
#
# :::

# %% [markdown]
# ## Resources/Tools
#
# Computational ability equivalent to those presented in ENGR 1330 are expected.
#
# ### Hardware Requirements
# The college of engineering has specific laptop requirements for courses that are listed at https://www.depts.ttu.edu/coe/dean/engineeringitservices/buyingtherightcomputer.php
#
# A minimal AWS Lightsail Instance (use Windows Server 2000 template; lowest resource provision tier; AWS RDP client, or download and install own RDP client) is sufficient to run the course software if you are incapable of installation onto your own laptop.
#
# ### Learning Management System
# Canvass is used as the learning management system (LMS) for this class and all exercises are to be uploaded to the LMS.  **Late submissions are accepted, but scores are automatically reduced by 50%**.
#
# ### Instructor Notes
# The instructor notes are located at [http://54.243.252.9/ce-3372-webroot/ce3372notebook/_build/html/intro.html](http://54.243.252.9/ce-3372-webroot/ce3372notebook/_build/html/intro.html)

# %% [markdown]
# # Course Schedule

# %% [markdown]
# |date|topic|readings|homework|
# |:---|:---|:---|:---|
# |14 Jan 2026|[1-Introduction](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/01-introduction/introduction.html) <br> - [Syllabus](http://54.243.252.9/ce-3372-webroot/ce3372notebook/_build/html/lessons/00-syllabus/ce-3372-syllabus-2026-1.html)<br> - [Water System Types](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/01-introduction/introduction.html#water-systems-definition-s)||- <font color="red">directive</font>|
# |16 Jan 2026|[2-Design Projects](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/02-projects/projects.html) <br> - [Distribution System Types](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/02-dwdesign/drinking_water_design/drinking_water_design.html#distribution-system-types)  <br> - [Guidance Documents](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/02-dwdesign/drinking_water_design/drinking_water_design.html#guidance-documents)  |[link](url) |- <font color="red">directive</font>|
# |19 Jan 2026|<font color="green">No Class (MLK Holiday)</font>|||
# |21 Jan 2026|[3-Drinking Water Design]() <br> - [Distribution System Types]()  <br> - [Guidance Documents]()  |[link](url) |- <font color="red">directive</font>|
# |23 Jan 2026|[4-Raw Water Transmission]() <br> - [Plan View Requirements](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/03-drawings/design_drawings/design_drawings.html#plan-view-requirements)  <br> - [Profile View Requirements](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/03-drawings/design_drawings/design_drawings.html#profile-elevation-view-requirements)  |[link](url) |- <font color="red">directive</font>|
# |26 Jan 2026|[5-Drawings and Maps](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/03-drawings/xyz2topo/xyz2topo.html) <br> - [Example](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/03-drawings/xyz2topo/xyz2topo.html#example) |[link](url) |- <font color="red">directive</font>|
# |28 Jan 2026|[6-Maps from XYZ](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/03-drawings/qgis_topography/qgis_topography.html) <br> - [QGIS vs ArcGIS](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/03-drawings/qgis_topography/qgis_topography.html#why-qgis-instead-of-esri-products)  <br> - [Making a Topo Map](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/03-drawings/qgis_topography/qgis_topography.html#making-a-topographic-map) |[link](url) |- <font color="red">directive</font>|
# |30 Jan 2026|[7-Maps using GIS](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/04-demands/demand-forcasting.html) <br> - [Population Forecasting](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/04-demands/demand-forcasting.html#population-forecasting)  <br> - [Average Daily Demand](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/04-demands/demand-forcasting.html#average-daily-demand-add)  |[link](url) |- <font color="red">directive</font>|
# |02 Feb 2026|[Pipeline Headloss](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/055-headloss/headloss.html) <br> - [Energy Equation](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/055-headloss/headloss.html#energy-equation)  <br> - [Head Loss Models](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/055-headloss/headloss.html#head-loss-models-for-losses-in-closed-conduits)  |[link](url) |- <font color="red">directive</font>|
# |04 Feb 2026|[Pipeline Hydraulics](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/05-pipeline_hydraulics/pipelinehydraulics.html#) <br> - [Example](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/05-pipeline_hydraulics/pipelinehydraulics.html#example-steady-discharge-between-reservoirs)  <br> - [Linking Systems](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/05-pipeline_hydraulics/pipelinehydraulics.html#linking-systems)  |[link](url) |- <font color="red">directive</font>|
# |06 Feb 2026|[Pumping Systems](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/06-pumping/pumps.html) <br> - [Pump Selection](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/06-pumping/pumps.html#pump-selection)  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |09-13 Feb 2026|<font color="green">No Class (Job Fair)</font>|||
# |16 Feb 2026|[Storage Systems](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/07-storage/storage.html) <br> - [Types of Storage](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/07-storage/storage.html#storage-systems-types)  <br> - [Purpose(s) of Storage](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/07-storage/storage.html#purposes)  |[link](url) |- <font color="red">directive</font>|
# |18 Feb 2026|[Pipe Networks](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/08-networks/networks.html) <br> - [Network Simulation](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/08-networks/networks.html#pipeline-network-simulation)  <br> - [Network Analysis Example (python)](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/08-networks/networks.html#network-analysis-example)  |[link](url) |- <font color="red">directive</font>|
# |20 Feb 2026|[Pipe Networks](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/08-networks/networks.html) <br> - [Network Analysis Example (Excel)](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/08-networks/networks.html#spreadsheet-solutions)  <br> - [EPANET](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/08-networks/networks.html#analysis-using-epanet)  |[link](url) |- <font color="red">directive</font>|
# |23 Feb 2026|[Pipeline Transients](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/12-pipeline_transients/pipeline_transients.html) <br> - [Rigid Column Theory](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/12-pipeline_transients/pipeline_transients.html#rigid-column-theory)  <br> - [Elastic Pipe Theory](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/12-pipeline_transients/pipeline_transients.html#elastic-pipe-theory)  |[link](url) |- <font color="red">directive</font>|
# |25 Feb 2026|[EPANET Introduction](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/13-epanet_intro/epanet_intro.html) <br> - [About EPANET](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/13-epanet_intro/epanet_intro.html#about-epanet)  <br> - [EPANET by Example](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/13-epanet_intro/epanet_intro.html#examples-from-epanet-by-example)  |[link](url) |- <font color="red">directive</font>|
# |27 Feb 2026|[EPANET Pumps, Pipes, and Valves](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/15-epanet_pumps/epanet_pumps.html) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |02 Mar 2026|[EPANET Extended Period Simulation](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/17-epanet_eps/epanet_eps.html)  <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |04 Mar 2026|[Stormwater Drainage Design](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/19-swdesign/swdesign.html) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |06 Mar 2026|[Initial Inlet Sizing](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/20-inletsizing/inlets.html) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |09 Mar 2026|[Initial Conduit Sizing](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |11 Mar 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |13 Mar 2026|[EPA SWMM Introduction](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/25-swmm_intro/swmm_intro.html) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |09 Mar 2026|[EPA SWMM Hydrology](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/25-swmm_intro/swmm_intro.html) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |11 Mar 2026|[EPA SWMM Conduits ](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |13 Mar 2026|[EPA SWMM Surface/Subsurface Hydraulics](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |14-22 Mar 2026|<font color="green">No Class (Spring Retreat)</font>|||
# |23 Mar 2026|[Green Infrastructure](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/21-greeninfrastructure/greeninfrastructure.html) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |25 Mar 2026|[Green Infrastructure and Water Quality](http://54.243.252.9/ce-3372-webroot/ce3372jb/_build/html/lessons/21-greeninfrastructure/21.1waterquality.html) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |27 Mar 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |30 Mar 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |01 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |03 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |06 Apr 2026|<font color="green">No Class (No-Classes Day)</font>|||
# |08 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |10 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |13 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |15 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |17 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |20 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |22 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |24 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |27 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |29 Apr 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |01 May 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |04 May 2026|[link](url) <br> - Topic 1  <br> - Topic 2  |[link](url) |- <font color="red">directive</font>|
# |12 May 2026|<span style="color:red; font-weight:bold;">Final Exam 7:30–10:00 PM</span>|[link](url) |- <font color="red">directive</font>|

# %% [markdown]
# ---
# ## Course Assessment and Grading Criteria:
# There will be 8-9 laboratory reports, 8-9 BB tests (quizzes), and practical Lab exam.
#
# **Late** assignments will incur a substantial penalty.
#
# Grades will be based on the following components; weighting is approximate:
#
# |Assessment Instrument|Weight(%)|
# |---|---:|
# |Attendance|10|
# |Laboratory Reports|40|
# |Laboratory Quizzes|30|
# |Lab Final Exam|20|
# |Overall total|100|
#
# Letter grades will be assigned using the following proportions:
#
# |Normalized Score Range|Letter Grade|
# |:-|---:|
# |≥ 90|A|
# |80-89|B|
# |70-79|C|
# |55-69|D|
# |< 55|F|
#
# <!-- Scores as Quantiles Ranges
# |81-100|A|
# |61-80|B|
# |41-60|C|
# |21-40|D|
# |0-20|F|
# -->

# %% [markdown]
# ## Classroom Policy:
# The following activities are not allowed in the classroom: Texting or talking on the cellphone or other electronic devices, and reading non-course related materials.  Use of cellphones cameras for recording phenomena is allowed

# %% [markdown]
# ## [Required Syllabus Statements (link to policy statement(s))](https://www.depts.ttu.edu/tlpdc/RequiredSyllabusStatements.php)
#
# ## [Recomended/Optional Statements (link to policy statement(s))](https://www.depts.ttu.edu/tlpdc/RecommendedSyllabusStatements.php)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b><h1>CE 3372 Water Systems Design</h1></b>
# </div>
#
# # Outfall Considerations
#
# ## Concepts
#
# - Bedload and Erosion
# - Velocity Control

# %% [markdown]
# ## End of Section

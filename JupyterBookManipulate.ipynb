# %%
! pwd
# Out:
# /home/webroot/ce-3372-webroot

# %%
! jupyter-book build ce3372jb
# Out:
# Running Jupyter-Book v1.0.2
# Source Folder: /home/webroot/ce-3372-webroot/ce3372jb
# Config Path: /home/webroot/ce-3372-webroot/ce3372jb/_config.yml
# Output Path: /home/webroot/ce-3372-webroot/ce3372jb/_build/html
# Running Sphinx v7.4.7
# loading translations [en]... done
# [etoc] Changing master_doc to 'intro'
# checking bibtex cache... out of date
# parsing bibtex file /home/webroot/ce-3372-webroot/ce3372jb/references.bib... parsed 5 entries
# ...
